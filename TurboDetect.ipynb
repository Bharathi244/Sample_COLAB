# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharathi244/Sample_COLAB/blob/main/TurboDetect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install keras==2.0.3

# %%
! git clone https://github.com/JayaasreeA/Turbo.git

# %%
# %cd Turbo/
# Out:
# /content/Turbo

# %%
! python train_frcnn.py -o simple -p annotate.txt

# %%
! python test_frcnn.py -p test_images
# Out:
# Streaming output truncated to the last 5000 lines.
# 2021-06-14 17:18:48.719519: I tensorflow/core/common_runtime/placer.cc:114] roi_pooling_conv_1/strided_slice_126/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# roi_pooling_conv_1/strided_slice_126/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2021-06-14 17:18:48.719550: I tensorflow/core/common_runtime/placer.cc:114] roi_pooling_conv_1/strided_slice_126/stack_2: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# roi_pooling_conv_1/strided_slice_127/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# 2021-06-14 17:18:48.719569: I tensorflow/core/common_runtime/placer.cc:114] roi_pooling_conv_1/strided_slice_127/stack: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# roi_pooling_conv_1/strided_slice_127/stack_1: (Const): /job:localhost/replica:0/task:0/device:GPU:0
# ...
